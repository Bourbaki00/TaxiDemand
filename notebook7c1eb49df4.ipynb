# %% [markdown]
# <a href="https://www.kaggle.com/code/nibourbaki/notebook7c1eb49df4?scriptVersionId=141673673" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# !git clone https://github.com/haotian-liu/LLaVA.git
# Out:
# Cloning into 'LLaVA'...
# remote: Enumerating objects: 1231, done.
# remote: Counting objects: 100% (456/456), done.
# remote: Compressing objects: 100% (86/86), done.
# remote: Total 1231 (delta 385), reused 391 (delta 370), pack-reused 775
# Receiving objects: 100% (1231/1231), 12.73 MiB | 18.65 MiB/s, done.
# Resolving deltas: 100% (745/745), done.

# %%
# !pip install -e ./LLaVA
# Out:
# Obtaining file:///kaggle/working/LLaVA
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Installing backend dependencies ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for llava (pyproject.toml) ... done
#   Created wheel for llava: filename=llava-1.0.1-0.editable-py3-none-any.whl size=14242 sha256=bb266169b667e789b650fd339699d75900f3fe49ee90a718ece1d1f5a896d7fd
#   Stored in directory: /tmp/pip-ephem-wheel-cache-746o42rz/wheels/48/ea/ca/3c02db38c529dcd9256d3c3820d0301a49d828da20359c47c0
# Successfully built llava
# ...
#   Attempting uninstall: llava
#     Found existing installation: llava 1.0.1
#     Uninstalling llava-1.0.1:
#       Successfully uninstalled llava-1.0.1
# ...

# %%
# !python ./LLaVA/scripts/merge_lora_weights.py --model-base meta-llama/Llama-2-7b-chat-hf --model-path liuhaotian/llava-llama-2-7b-chat-lightning-lora-preview  --save-model-path /kaggle/working/llva-llama-2-7B/
# Out:
# ...
# Loading checkpoint shards: 100%|██████████████████| 2/2 [00:01<00:00,  1.99it/s]
# Some weights of LlavaLlamaForCausalLM were not initialized from the model checkpoint at meta-llama/Llama-2-7b-chat-hf and are newly initialized: ['model.mm_projector.bias', 'model.mm_projector.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ...
# Loading additional LLaVA weights...
# ...
# Loading LoRA weights...
# ...
# Merging LoRA weights...
# Model is loaded...

# %%
# !huggingface-cli login --token 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

# %%
# Assuming your input file is named "input.txt"
input_path = "/kaggle/working/LLaVA/llava/model/builder.py"

# Read the content of the file
with open(input_path, "r") as file:
    content = file.read()

# Modify the content
modified_content = content.replace(
"""
        vision_tower = model.get_vision_tower()
        if not vision_tower.is_loaded:
            vision_tower.load_model()
        vision_tower.to(device='cuda', dtype=torch.float16)
        image_processor = vision_tower.image_processor
""", "")

# Write the modified content back to the file
with open(input_path, "w") as file:
    file.write(modified_content)
print(modified_content)

# %%
# !git clone https://huggingface.co/shauray/llva-llama-2-7B

# %%
# !cd llva-llama-2-7B/ && git add pytorch_model-00002-of-00002.bin && git commit -m "file" && git push
# Out:
# [main fd18b76] file
#  1 file changed, 3 insertions(+)
#  create mode 100644 pytorch_model-00002-of-00002.bin
# Username for 'https://huggingface.co': ^C

# %%
# !git config --global user.email "shauraysingh08@gmail.com"
# !git config --global user.name "shauray"

# %%
# !cd llva-llama-2-7B/ && git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	config.json
# 	generation_config.json
# 	pytorch_model-00001-of-00002.bin
# 	pytorch_model-00002-of-00002.bin
# 	pytorch_model.bin.index.json
# 	special_tokens_map.json
# 	tokenizer.model
# 	tokenizer_config.json
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !rm -rf /kaggle/working/llva-llama-2-7B/pytorch_model.bin.index.json /kaggle/working/llva-llama-2-7B/tokenizer_config.json /kaggle/working/llva-llama-2-7B/generation_config.json

# %%
# !cd llva-llama-2-7B/ && git push
# Out:
# Username for 'https://huggingface.co': ^C

# %%
# !huggingface-cli whoami
# Out:
# shauray

# %%
import subprocess

# Replace these variables with your actual values
huggingface_username = "shauray"
personal_access_token = "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"
repository_url = "https://huggingface.co/shauray/llva-llama-2-7B"

# Set Git global configuration for username and email
subprocess.run(['git', 'config', '--global', 'user.name', huggingface_username])
subprocess.run(['git', 'config', '--global', 'user.email', 'shauraysingh08@gmail.com'])

# Commit your changes
#subprocess.run(['git', 'add', '.'])
#subprocess.run(['git', 'commit', '-m', 'Your commit message here'])

# Push to the Hugging Face repository
push_command = f'git push {repository_url} main'
# Use a personal access token for authentication
subprocess.run(['git', 'push', repository_url], input=personal_access_token, text=True)

print("Push successful.")
# Out:
# Push successful.
# fatal: not a git repository (or any parent up to mount point /kaggle)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
# !echo "shauraysingh08@gmail.com" | cd llva-llama-2-7B/ && git push
# Out:
# fatal: not a git repository (or any parent up to mount point /kaggle)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
# !cd llva-llama-2-7B/ && echo "shauray" | git push

# %%
# !ls
